# %% [markdown]
# # Homework 2
# ### By: Alexis Morse

# %% [markdown]
# ## 1. Consider the optimization problem
# ## $$ \min_{x1 ,x2 ,x3 ,x4} f(x)=x^2_1 +2x^2_2 +x^2_3 −2x_3x_4 +x^2_4 +2x_1 − 4x_2 + 4$$
#
# - • Find the gradient of the objective function ∇f(x).

# %% [markdown]
# ![gradienthw2382.jpeg](attachment:gradienthw2382.jpeg)

# %% [markdown]
# -  If we apply the gradient descent with stepsize ν and the initial point is (0,0,0,0), what is the next iterator?
# ![matrixgradien%20t.jpg](attachment:matrixgradien%20t.jpg)

# %% [markdown]
# -  What is the minimum value of f(x)?
# ![globalmin.jpg](attachment:globalmin.jpg)
# #### There is an infinite global minimum at 1 because when you plug values into the hessian and solve for $\lambda$ and then plug in the $\lambda$ values back into the main equation above, you get a min value of 1.

# %% [markdown]
#  • Is there a unique solution for the problem?
# #### No because one of solutions is infinite.  Its infinite because $X_3$ and $X_4$ will have infinitely many solutions.

# %% [markdown]
# ## 2. What are three ways to compute the stepsize $t_k$ in the gradient and the schematic descent directions methods? Please describe in detail and give any necessary formulas or expressions. What is a disadvantage of the constant stepsize method? What is a disadvantage of exact line search?

# %% [markdown]
# The three ways to compute the stepsize $t_k$ are stated below
#
# - Pick a constant value $t_k =t$ for all $k$
#
#
#
# - Solve via exact line search $t_k = argminf(x_k + td_k)$
#
#
#
# - Solve via back tracking line search $t_k = ( f(x_k) - f(x_k +t_kd_k) ) >= - \alpha t_k \triangledown f(x_k)^T d_k $
#
# A disadvantage of constant step size method is that if t is too big, the the sol will not be accurate. If t is too small, the guess barely changes
#
# A disadvantage of exact line search is that it is really difficult to solve the problem sometimes

# %% [markdown]
# ## 3. Consider the loss function for the ridge regression
# $$f(x) = \frac{1}{2} ||Ax − b||^2_2 + λ||x||^2 $$
# Compute its gradient ∇f(x).

# %% [markdown]
# ![proofgradient.jpg](attachment:proofgradient.jpg)
