# %% [markdown]
# ## Homework 4
#
# ### By: Alexis Morse

# %% [markdown]
# ![Q1HW382.png](attachment:Q1HW382.png)

# %% [markdown]
# ![q1cmse.jpg](attachment:q1cmse.jpg)

# %% [markdown]
# ![Q2HW382.png](attachment:Q2HW382.png)

# %% [markdown]
# ![q2cmse.jpg](attachment:q2cmse.jpg)

# %% [markdown]
# ###### 3. Why is $f(x)$ $=$ $x^2_1$ $−$ $x^4_2$ not convex, with $x ∈ R^2$?

# %% [markdown]
# ![q3cmse.jpg](attachment:q3cmse.jpg)
