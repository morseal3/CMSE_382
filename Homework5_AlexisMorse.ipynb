# %% [markdown]
# ## Homework 5
# ### By: Alexis Morse

# %% [markdown]
# #### 1. Is the following optimization problem convex? Why or why not?

# %% [markdown]
# ![prob1hw5382.png](attachment:prob1hw5382.png)

# %% [markdown]
# ![q1hw5382.jpg](attachment:q1hw5382.jpg)

# %% [markdown]
# #### 2. Explain why the following optimization problem has at most one optimal solution.

# %% [markdown]
# ![prob2hw5382.png](attachment:prob2hw5382.png)

# %% [markdown]
# ![hw5q2382.jpg](attachment:hw5q2382.jpg)

# %% [markdown]
# #### 3. A shop would like to prepare a signature fertilizer at a minimal cost by mixing two fertilizers, fertilizer A and fertilizer B.
#
# #### The owners would like the mixture to contain at least 30 units of phosphate, at least 40 units of nitrate and at least 45 units of ammonium.
#
# #### Fertilizer A costs the shop 1 dollar per pound. Fertilizer B costs the shop 2 dollar per pound.
#
# #### Fertilizer A contains 6 units of phosphate, 2 units of nitrate and 3 units of ammonium.    Fertilizer B contains 4 units of phosphate, 4 units of nitrate and 5 units of ammonium.
#
# #### What is the linear programming optimization problem that needs to be solved in order to figure out how many pounds of each fertilizer the shop needs to use to minimize its cost? No need to solve the problem.

# %% [markdown]
#                                                              -   min 1x + 2y = min cost
#         - x = pounds of fertilizer A            s.t.              x >= 0 & y >= 0
#         - y = pounds of fertilizer B                               6x + 4y = 30
#                                                                    2x + 4y = 40
#                                                                    3x + 5y = 45

# %% [markdown]
# #### 4. What equations/inequalities need to be solved for the following problems in order to obtain their stationary points; they should be particular to the convex set. Find the stationary points for the first and third problem. Recall that we are considering the minimization of a function over a closed and convex set C.

# %% [markdown]
# ![prob4hw5382.png](attachment:prob4hw5382.png)

# %% [markdown]
# ![newq4382.jpg](attachment:newq4382.jpg)

# %% [markdown]
# #### 5. This problem involves questions from Chapter 9.
#     • How is the gradient projection method different from the gradient method and what problem does it solve?
#
#     • What problem does the iterative hard-thresholding method solve?

# %% [markdown]
# ##### (a)
#  There are two differences that distinct the gradient projection method from the gradient method. The problems solves for if the function converges to a minimum value within the convex set. You can also estimate the rate of convergence. The function will converge close to the stationary point of the function.
#
#  - The equation to update $x_{k+1}$ is different :       $ x_{k+1} = P_c(x_k - t_k \triangledown f(x_k))$
#  - The stopping criteria cant use $ ||\triangledown  f(x_k) || < \delta $ since $x \in C$ so the new stopping criteria is $||x_k - x_{k+1}|| <= \delta$

# %% [markdown]
# ##### (b)
# $$\min\limits_{\mathbf{x}}~{\|\mathbf{A}\mathbf{x}-\mathbf{b}\|^2}\quad\mbox{ s.t. } \|\mathbf{x}\|_0\leq s.$$

# %% [markdown]
#     The iterative hard-thresholding method tries to converge to a local minimum x value by following a generialized component of the gradient projection method of the function while aimed at enforcing the L-stationary point condition. Starting at $x_0$ and finishing when finding the minimum value x within the convex set, which will be a stationary point.
